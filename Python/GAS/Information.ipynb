# %% [markdown]
# # 입시정보
# **************************************
# * ** 한국산업기술대학교 **
# > * 교과(175) : 최저 국,수,탐 중 2개 합 6등급 (가형 1등급 가산), 학생부 100,
# > * 논술전형신설(150) : 최저학력없음, 논술 60 + 학생부 40, 수리논술 2문제 80분
# > * 적성고사(300) : 최저학력없음, 학생부60 + 적성 40, 국어30 + 수학30 = 70분
# > * 정시(242) : 수능 80 + 학생부 20, 국어 30, 수학 40, 탐구 30 / 가형 10%가산, 영어 2등급, 한국사 4등급 이내 10점 가산
# > * 수능우수자(241) : 수능 100, 나머지는 위와 동일.
#
# * ** 한국기술교육대학교 **
# > * 학생부교과(172) : 최저 수학+영어+(국어 or 탐구) 합 10.0 이내 (가형 2등급 가산), 학생부 100, 2:4:4
# > * 정시(180) : 수능 100, 국어 20 + 수학 35 + 영어 20 + 탐구 25 (가형 20%, 과탐 10% 가산) -> 20:42:20:27.5
#
# * ** 경기대학교(수원) **
# > * 교과(772) : 최저 상위 3개 등급합 12, 학생부 100, 가중치 없음
# > * 정시(563) : 수능 80 + 학생부 20, 국어 30 + 수학 40 + 영어 20 + 과학 10 -> 3:4:2:1
#
# * ** 인천대학교 **
# > * 정시(998) : 수능 100, 국어 300 + 수학 400 + 과학 300 + 영어 감점 (2등급:-4, 3등급:-11, 4등급:-20) -> 3:4:0.1:3
#
# * ** 단국대학교 **
# > * 논술(360) : 최저학력없음, 논술 60 + 학생부 40, 수리논술 2문제, 학생부 2:3:3:2
# > * 정시(269) : 수능 100, 국어 20 + 수학 35 + 영어 20 + 탐구 25 (가형 15% 가산) -> 20:40.25:20:25
#
# * ** 아주대학교 **
# > * 논술(226) : 최저학력없음, 논술 70 + 학생부 30, 학생부 2:4:4, 2:3:3:2
# > * 정시(288) : 수능 100, 국어 20 + 수학 30 + 영어 20 + 과학 30, 영어변환점수(120기준 등급당 1점감점) -> 2:3:2:3
#
# * ** 상명대학교 **
# > * 정시(363) : 수능 100, 25:35:20:20 (가형 가산 10%), 영어 (100기준 등급당 2점감점) -> 25:38.4:20:20
#
# * ** 가천대학교 **
# > * 교과(472) : 최저 2개합 6, 학생부 100, 국수영과 점수 높은 순으로 35:25:25:15 반영 + 교과별 우수 4과목반영, 1:1:1
# > * 적성(999) : 최저학력없음, 학생부 60 + 적성 40
# > * 정시(800) : 수능 100, 25:30:25:20 (가형 가산 7%, 과학 가산 5%)
#
#
# # 입시통계
# *************************************
# * ** 한국산업기술대학교 **
# 	* 교과
#     	>* 컴퓨터과학과 : 3.2
#         >* 소프트웨어 : 3.0
#         >* 게임공학 : 2.8
#     * 정시
#         >* 컴퓨터과학과 : 76.1 (평균점수)
#         >* 소프트웨어 : 78.5 (평균점수)
#
#
# * ** 한국기술교육대학교 **
# 	* 교과
#     	>* 컴퓨터공학과 : 2.86
#     * 정시
#         >* 컴퓨터공학부 : 84.1 (백분위)
#
#
# * ** 경기대학교 **
# 	* 교과
#     	>* 컴퓨터과학과 : 3.3
#         >* 융합보안학과 : 3.1
#     * 정시
#         >* 컴퓨터과학과 : 3.3, 3.9, 3.4, 3.1 -> 3.54
#
#
# * ** 인천대학교 **
#     * 정시
#         >* 컴퓨터공학과 : 3.5, 4.1, 4, 3.6 ->  4.14
#
#
# * ** 단국대학교 **
#     * 정시
#         >* 응용컴퓨터공학과 : 80.87
#
#
# * ** 아주대학교 **
#     * 정시
#         >* 정보컴퓨터공학과 : 85
#
#
# * ** 상명대학교**
#     * 정시
#         >* 컴퓨터과학과 : 2.83
#         >* 게임학과 : 2.83
#
#
# * ** 가천대학교 **
#     * 정시
#         >* 컴퓨터공학과 : 79.5 (백분위)

# %%
35 * 1.20, 25 * 1.1
# Out:
# (42.0, 27.500000000000004)

# %%
(3.3 * 3 + 3.9 * 4 + 3.4 * 2 + 3.1 * 1)/10
# Out:
# 3.54

# %%
(3.5 * 3 + 4.1 * 4 + 3.6 * 3 + 4 + 0.1)/10.1
# Out:
# 4.13861386138614

# %%
35 * 1.15
# Out:
# 40.25
